# %% [markdown]
# Lab
# ===================
# Twitter & MongoDB
# -------------------
# Alessandro D. Gagliardi

# %% [markdown]
# Importing Libraries
# -------------------

# %%
# standard library:
import os  

from pprint import pprint

# other modules:
import matplotlib.pyplot as plt
import pandas as pd
import twitter
import yaml

from pymongo import MongoClient

# %% [markdown]
# Twitter Trends
# ==============

# %% [markdown]
# ### Connect to Twitter:

# %%
credentials = yaml.load(open(os.path.expanduser('~/api_cred.yml')))

auth = twitter.oauth.OAuth(credentials['ACCESS_TOKEN'], 
                           credentials['ACCESS_TOKEN_SECRET'],
                           credentials['API_KEY'],
                           credentials['API_SECRET'])

twitter_api = twitter.Twitter(auth=auth)

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

pprint(world_trends)
# Out:
# [{u'as_of': u'2014-04-29T00:10:34Z',
#   u'created_at': u'2014-04-29T00:05:25Z',
#   u'locations': [{u'name': u'Worldwide', u'woeid': 1}],
#   u'trends': [{u'name': u'#bbwlareunion',
#                u'promoted_content': None,
#                u'query': u'%23bbwlareunion',
#                u'url': u'http://twitter.com/search?q=%23bbwlareunion'},
#               {u'name': u'#BieberStoleFromParamore',
#                u'promoted_content': None,
#                u'query': u'%23BieberStoleFromParamore',
#                u'url': u'http://twitter.com/search?q=%23BieberStoleFromParamore'},
#               {u'name': u'#WeWereBornForThis',
#                u'promoted_content': None,
#                u'query': u'%23WeWereBornForThis',
#                u'url': u'http://twitter.com/search?q=%23WeWereBornForThis'},
#               {u'name': u'#DisneyKids',
#                u'promoted_content': None,
#                u'query': u'%23DisneyKids',
#                u'url': u'http://twitter.com/search?q=%23DisneyKids'},
#               {u'name': u'#UnaVezMeConquistaron',
#                u'promoted_content': None,
#                u'query': u'%23UnaVezMeConquistaron',
#                u'url': u'http://twitter.com/search?q=%23UnaVezMeConquistaron'},
#               {u'name': u'Zayn Is An Angel',
#                u'promoted_content': None,
#                u'query': u'%22Zayn+Is+An+Angel%22',
#                u'url': u'http://twitter.com/search?q=%22Zayn+Is+An+Angel%22'},
#               {u'name': u'Clara Vende a Alian\xe7a e Ajuda a Marina',
#                u'promoted_content': None,
#                u'query': u'%22Clara+Vende+a+Alian%C3%A7a+e+Ajuda+a+Marina%22',
#                u'url': u'http://twitter.com/search?q=%22Clara+Vende+a+Alian%C3%A7a+e+Ajuda+a+Marina%22'},
#               {u'name': u'Tim McCarver',
#                u'promoted_content': None,
#                u'query': u'%22Tim+McCarver%22',
#                u'url': u'http://twitter.com/search?q=%22Tim+McCarver%22'},
#               {u'name': u'No Naya No Glee',
#                u'promoted_content': None,
#                u'query': u'%22No+Naya+No+Glee%22',
#                u'url': u'http://twitter.com/search?q=%22No+Naya+No+Glee%22'},
#               {u'name': u'Partiu Demi',
#                u'promoted_content': None,
#                u'query': u'%22Partiu+Demi%22',
#                u'url': u'http://twitter.com/search?q=%22Partiu+Demi%22'}]}]

# %%
pprint(us_trends)
# Out:
# [{u'as_of': u'2014-04-29T00:10:34Z',
#   u'created_at': u'2014-04-29T00:10:00Z',
#   u'locations': [{u'name': u'United States', u'woeid': 23424977}],
#   u'trends': [{u'name': u'#bbwlareunion',
#                u'promoted_content': None,
#                u'query': u'%23bbwlareunion',
#                u'url': u'http://twitter.com/search?q=%23bbwlareunion'},
#               {u'name': u'#ADAMNOTICEMAHOGANY',
#                u'promoted_content': None,
#                u'query': u'%23ADAMNOTICEMAHOGANY',
#                u'url': u'http://twitter.com/search?q=%23ADAMNOTICEMAHOGANY'},
#               {u'name': u'#FastNLive',
#                u'promoted_content': None,
#                u'query': u'%23FastNLive',
#                u'url': u'http://twitter.com/search?q=%23FastNLive'},
#               {u'name': u'#RixtonOnTheVoice',
#                u'promoted_content': None,
#                u'query': u'%23RixtonOnTheVoice',
#                u'url': u'http://twitter.com/search?q=%23RixtonOnTheVoice'},
#               {u'name': u'Sundy',
#                u'promoted_content': None,
#                u'query': u'Sundy',
#                u'url': u'http://twitter.com/search?q=Sundy'},
#               {u'name': u'#DisneyKids',
#                u'promoted_content': None,
#                u'query': u'%23DisneyKids',
#                u'url': u'http://twitter.com/search?q=%23DisneyKids'},
#               {u'name': u'John Sally',
#                u'promoted_content': None,
#                u'query': u'%22John+Sally%22',
#                u'url': u'http://twitter.com/search?q=%22John+Sally%22'},
#               {u'name': u'Wyatt',
#                u'promoted_content': None,
#                u'query': u'Wyatt',
#                u'url': u'http://twitter.com/search?q=Wyatt'},
#               {u'name': u'Damn Draya',
#                u'promoted_content': None,
#                u'query': u'%22Damn+Draya%22',
#                u'url': u'http://twitter.com/search?q=%22Damn+Draya%22'},
#               {u'name': u'Reigns vs Orton',
#                u'promoted_content': None,
#                u'query': u'%22Reigns+vs+Orton%22',
#                u'url': u'http://twitter.com/search?q=%22Reigns+vs+Orton%22'}]}]

# %% [markdown]
# ### Do any of these trends intersect?

# %%
[trend['name'] for trends in world_trends
                        for trend in trends['trends']]
# Out:
# [u'#bbwlareunion',
#  u'#BieberStoleFromParamore',
#  u'#WeWereBornForThis',
#  u'#DisneyKids',
#  u'#UnaVezMeConquistaron',
#  u'Zayn Is An Angel',
#  u'Clara Vende a Alian\xe7a e Ajuda a Marina',
#  u'Tim McCarver',
#  u'No Naya No Glee',
#  u'Partiu Demi']

# %%
world_trends_set = set([trend['name'] for trends in world_trends
                        for trend in trends['trends']])
world_trends_set
# Out:
# {u'#BieberStoleFromParamore',
#  u'#DisneyKids',
#  u'#UnaVezMeConquistaron',
#  u'#WeWereBornForThis',
#  u'#bbwlareunion',
#  u'Clara Vende a Alian\xe7a e Ajuda a Marina',
#  u'No Naya No Glee',
#  u'Partiu Demi',
#  u'Tim McCarver',
#  u'Zayn Is An Angel'}

# %%
us_trends_set = set([trend['name'] for trends in us_trends
                     for trend in trends['trends']])

# %%
world_trends_set.intersection(us_trends_set)
# Out:
# {u'#DisneyKids', u'#bbwlareunion'}

# %% [markdown]
# Twitter Statuses
# ================

# %%
q = world_trends[0]['trends'][0]['name']
q
"""
world_trends=
[{u'as_of': u'2014-04-24T03:05:31Z',
  u'created_at': u'2014-04-24T03:03:41Z',
  u'locations': [{u'name': u'United States', u'woeid': 23424977}],
  u'trends': [{u'name': u'#BBQChickenAlert',
  ...
  }]
}]
  """
# Out:
# "\nworld_trends=\n[{u'as_of': u'2014-04-24T03:05:31Z',\n  u'created_at': u'2014-04-24T03:03:41Z',\n  u'locations': [{u'name': u'United States', u'woeid': 23424977}],\n  u'trends': [{u'name': u'#BBQChickenAlert',\n  ...\n  }]\n}]\n  "

# %%
count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']

# %%
len(statuses)
# Out:
# 100

# %% [markdown]
# ### More?

# %%
search_results['search_metadata'].get('next_results')
# Out:
# u'?max_id=460934197880705023&q=%23bbwlareunion&count=100&include_entities=1'

# %%
if 'next_results' in search_results['search_metadata']:
    next_results = search_results['search_metadata']['next_results']
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

len(statuses)
# Out:
# 200

# %% [markdown]
# Mongo
# =====

# %% [markdown]
# from the command line:
# ```bash
# $ mkdir -p data/db
# $ mongod --dbpath data/db
# ```

# %% [markdown]
# ### Connect to our Mongo database management server (DBMS):

# %%
c = MongoClient()

# %% [markdown]
# #### Create a database called `twitter`:

# %%
db = c.twitter

# %% [markdown]
# ##### Yes, it's that easy.

# %% [markdown]
# #### Insert the results we pulled from Twitter and store them as a document in a collection named `tweets`:

# %%
statuses_ids = db.tweets.insert(statuses)
statuses_ids[:5]
# Out:
# [ObjectId('535eef6b40a70518e1474360'),
#  ObjectId('535eef6b40a70518e1474361'),
#  ObjectId('535eef6b40a70518e1474362'),
#  ObjectId('535eef6b40a70518e1474363'),
#  ObjectId('535eef6b40a70518e1474364')]

# %% [markdown]
# ### `ObjectId`s

# %% [markdown]
# **ObjectId** is a 12-byte **BSON** type, constructed using:
#
# -    a 4-byte value representing the seconds since the Unix epoch,
# -    a 3-byte machine identifier,
# -    a 2-byte process id, and
# -    a 3-byte counter, starting with a random value.
#
# In MongoDB, documents stored in a collection require a unique `_id` field that acts as a **primary key**. Because ObjectIds are small, most likely unique, and fast to generate, MongoDB uses ObjectIds as the default value for the `_id` field if the `_id` field is not specified.
#
# <!--small><i>from http://docs.mongodb.org/manual/reference/object-id/</i></small-->

# %% [markdown]
# Using ObjectIds for the `_id` field provides the following additional benefits:
#
# - you can access the insertion time of the ObjectId, using the `.generation_time` property in pymongo.
# - sorting on an `_id` field that stores ObjectId values is roughly equivalent to sorting by insertion time.

# %% [markdown]
# ### Test the contents of our database:

# %%
c.database_names()
# Out:
# [u'local', u'twitter', u'admin']

# %%
db = c.twitter
db.collection_names()
# Out:
# [u'tweets', u'system.indexes']

# %%
db.tweets.find_one()
# Out:
# {u'_id': ObjectId('535eef6b40a70518e1474362'),
#  u'contributors': None,
#  u'coordinates': None,
#  u'created_at': u'Tue Apr 29 00:10:58 +0000 2014',
#  u'entities': {u'hashtags': [{u'indices': [49, 62], u'text': u'bbwlareunion'}],
#   u'symbols': [],
#   u'urls': [],
#   u'user_mentions': []},
#  u'favorite_count': 0,
#  u'favorited': False,
#  u'geo': None,
#  u'id': 460934226783645696L,
#  u'id_str': u'460934226783645696',
#  u'in_reply_to_screen_name': None,
#  u'in_reply_to_status_id': None,
#  u'in_reply_to_status_id_str': None,
#  u'in_reply_to_user_id': None,
#  u'in_reply_to_user_id_str': None,
#  u'lang': u'en',
#  u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#  u'place': None,
#  u'retweet_count': 0,
#  u'retweeted': False,
#  u'source': u'<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iOS</a>',
#  u'text': u'Wait\u2026the mama posted her daughter\u2019s sex pic??!!! #bbwlareunion',
#  u'truncated': False,
#  u'user': {u'contributors_enabled': False,
#   u'created_at': u'Mon May 16 15:35:04 +0000 2011',
#   u'default_profile': False,
#   u'default_profile_image': False,
#   u'description': u'Fried crawfish meets foie gras...basically.',
#   u'entities': {u'description': {u'urls': []},
#    u'url': {u'urls': [{u'display_url': u'youtube.com/watch?v=YniH7u\u2026',
#       u'expanded_url': u'http://www.youtube.com/watch?v=YniH7uRj63I',
#       u'indices': [0, 22],
#       u'url': u'http://t.co/Whqf8AH7dx'}]}},
#   u'favourites_count': 63,
#   u'follow_request_sent': False,
#   u'followers_count': 605,
#   u'following': False,
#   u'friends_count': 533,
#   u'geo_enabled': False,
#   u'id': 299716997,
#   u'id_str': u'299716997',
#   u'is_translation_enabled': False,
#   u'is_translator': False,
#   u'lang': u'en',
#   u'listed_count': 10,
#   u'location': u'Gentilly Terrace, New Orleans',
#   u'name': u'I Love Teena Marie',
#   u'notifications': False,
#   u'profile_background_color': u'131516',
#   u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/771331342/b1d1650a0d81ab0944272ddf9011233a.jpeg',
#   u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/771331342/b1d1650a0d81ab0944272ddf9011233a.jpeg',
#   u'profile_background_tile': True,
#   u'profile_image_url': u'http://pbs.twimg.com/profile_images/378800000372541678/0ab722638eb1e530b613238e88b48307_normal.jpeg',
#   u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/378800000372541678/0ab722638eb1e530b613238e88b48307_normal.jpeg',
#   u'profile_link_color': u'C70C9B',
#   u'profile_sidebar_border_color': u'000000',
#   u'profile_sidebar_fill_color': u'0B1B09',
#   u'profile_text_color': u'335030',
#   u'profile_use_background_image': False,
#   u'protected': False,
#   u'screen_name': u'Jolie504',
#   u'statuses_count': 29997,
#   u'time_zone': u'Central Time (US & Canada)',
#   u'url': u'http://t.co/Whqf8AH7dx',
#   u'utc_offset': -18000,
#   u'verified': False}}

# %% [markdown]
# Notice the `_id` included in the document along with the values we already saw before.

# %% [markdown]
# Now that we have our data in MongoDB, we can use some of it's search functionality. For example:

# %%
popular_tweets = db.tweets.find({'retweet_count': {"$gte": 3}})
popular_tweets.count()
# Out:
# 26

# %% [markdown]
# Making Sense with Pandas
# ========================

# %%
db.tweets.find(fields=['created_at', 'retweet_count', 'favorite_count'])

# %%
pd.DataFrame(list(db.tweets.find(fields=['created_at', 'retweet_count', 'favorite_count'])))
# Out:
#                          _id                      created_at  favorite_count  \
# 0   535eef6b40a70518e1474362  Tue Apr 29 00:10:58 +0000 2014               0
# 1   535eef6b40a70518e1474366  Tue Apr 29 00:10:57 +0000 2014               0
# 2   535eef6b40a70518e1474360  Tue Apr 29 00:10:58 +0000 2014               0
# 3   535eef6b40a70518e1474361  Tue Apr 29 00:10:58 +0000 2014               0
# 4   535eef6b40a70518e1474363  Tue Apr 29 00:10:57 +0000 2014               0
# 5   535eef6b40a70518e1474364  Tue Apr 29 00:10:57 +0000 2014               0
# 6   535eef6b40a70518e1474365  Tue Apr 29 00:10:57 +0000 2014               0
# 7   535eef6b40a70518e1474367  Tue Apr 29 00:10:57 +0000 2014               0
# 8   535eef6b40a70518e1474368  Tue Apr 29 00:10:57 +0000 2014               0
# 9   535eef6b40a70518e1474369  Tue Apr 29 00:10:57 +0000 2014               0
# 10  535eef6b40a70518e147436a  Tue Apr 29 00:10:57 +0000 2014               0
# 11  535eef6b40a70518e147436b  Tue Apr 29 00:10:57 +0000 2014               0
# 12  535eef6b40a70518e147436c  Tue Apr 29 00:10:57 +0000 2014               0
# 13  535eef6b40a70518e147436d  Tue Apr 29 00:10:57 +0000 2014               0
# 14  535eef6b40a70518e147436e  Tue Apr 29 00:10:57 +0000 2014               0
# 15  535eef6b40a70518e147436f  Tue Apr 29 00:10:57 +0000 2014               0
# 16  535eef6b40a70518e1474370  Tue Apr 29 00:10:57 +0000 2014               0
# 17  535eef6b40a70518e1474371  Tue Apr 29 00:10:57 +0000 2014               0
# 18  535eef6b40a70518e1474372  Tue Apr 29 00:10:57 +0000 2014               0
# 19  535eef6b40a70518e1474373  Tue Apr 29 00:10:56 +0000 2014               0
# 20  535eef6b40a70518e1474374  Tue Apr 29 00:10:56 +0000 2014               0
# 21  535eef6b40a70518e1474375  Tue Apr 29 00:10:56 +0000 2014               0
# 22  535eef6b40a70518e1474376  Tue Apr 29 00:10:56 +0000 2014               0
# 23  535eef6b40a70518e1474377  Tue Apr 29 00:10:56 +0000 2014               0
# 24  535eef6b40a70518e1474378  Tue Apr 29 00:10:56 +0000 2014               0
# 25  535eef6b40a70518e1474379  Tue Apr 29 00:10:56 +0000 2014               0
# 26  535eef6b40a70518e147437a  Tue Apr 29 00:10:56 +0000 2014               0
# 27  535eef6b40a70518e147437b  Tue Apr 29 00:10:56 +0000 2014               0
# 28  535eef6b40a70518e147437c  Tue Apr 29 00:10:56 +0000 2014               0
# 29  535eef6b40a70518e147437d  Tue Apr 29 00:10:56 +0000 2014               0
# 30  535eef6b40a70518e147437e  Tue Apr 29 00:10:56 +0000 2014               0
# 31  535eef6b40a70518e147437f  Tue Apr 29 00:10:56 +0000 2014               0
# 32  535eef6b40a70518e1474380  Tue Apr 29 00:10:56 +0000 2014               0
# 33  535eef6b40a70518e1474381  Tue Apr 29 00:10:55 +0000 2014               0
# 34  535eef6b40a70518e1474382  Tue Apr 29 00:10:55 +0000 2014               0
# 35  535eef6b40a70518e1474383  Tue Apr 29 00:10:55 +0000 2014               0
# 36  535eef6b40a70518e1474384  Tue Apr 29 00:10:55 +0000 2014               0
# 37  535eef6b40a70518e1474385  Tue Apr 29 00:10:55 +0000 2014               0
# 38  535eef6b40a70518e1474386  Tue Apr 29 00:10:55 +0000 2014               0
# 39  535eef6b40a70518e1474387  Tue Apr 29 00:10:55 +0000 2014               0
# 40  535eef6b40a70518e1474388  Tue Apr 29 00:10:55 +0000 2014               0
# 41  535eef6b40a70518e1474389  Tue Apr 29 00:10:55 +0000 2014               0
# 42  535eef6b40a70518e147438a  Tue Apr 29 00:10:55 +0000 2014               0
# 43  535eef6b40a70518e147438b  Tue Apr 29 00:10:55 +0000 2014               0
# 44  535eef6b40a70518e147438c  Tue Apr 29 00:10:55 +0000 2014               0
# 45  535eef6b40a70518e147438d  Tue Apr 29 00:10:55 +0000 2014               0
# 46  535eef6b40a70518e147438e  Tue Apr 29 00:10:55 +0000 2014               0
# 47  535eef6b40a70518e147438f  Tue Apr 29 00:10:55 +0000 2014               0
# 48  535eef6b40a70518e1474390  Tue Apr 29 00:10:55 +0000 2014               0
# 49  535eef6b40a70518e1474391  Tue Apr 29 00:10:55 +0000 2014               0
# 50  535eef6b40a70518e1474392  Tue Apr 29 00:10:54 +0000 2014               0
# 51  535eef6b40a70518e1474393  Tue Apr 29 00:10:54 +0000 2014               0
# 52  535eef6b40a70518e1474394  Tue Apr 29 00:10:54 +0000 2014               0
# 53  535eef6b40a70518e1474395  Tue Apr 29 00:10:54 +0000 2014               0
# 54  535eef6b40a70518e1474396  Tue Apr 29 00:10:54 +0000 2014               0
# 55  535eef6b40a70518e1474397  Tue Apr 29 00:10:54 +0000 2014               0
# 56  535eef6b40a70518e1474398  Tue Apr 29 00:10:54 +0000 2014               0
# 57  535eef6b40a70518e1474399  Tue Apr 29 00:10:54 +0000 2014               0
# 58  535eef6b40a70518e147439a  Tue Apr 29 00:10:54 +0000 2014               0
# 59  535eef6b40a70518e147439b  Tue Apr 29 00:10:54 +0000 2014               0
#                          ...                             ...             ...
#
#     retweet_count
# 0               0
# 1               0
# 2               1
# 3               7
# 4               0
# 5               0
# 6               0
# 7               3
# 8               0
# 9               0
# 10              0
# 11              1
# 12              0
# 13              2
# 14              0
# 15              0
# 16              0
# 17              0
# 18              1
# 19              0
# 20              6
# 21             64
# 22              0
# 23              0
# 24              0
# 25              0
# 26              0
# 27              0
# 28              0
# 29              0
# 30             23
# 31              0
# 32              0
# 33              0
# 34              0
# 35              0
# 36              0
# 37              0
# 38              0
# 39              0
# 40              0
# 41              0
# 42              0
# 43              0
# 44              0
# 45              5
# 46              2
# 47              6
# 48              0
# 49              1
# 50              0
# 51              0
# 52              0
# 53              5
# 54              0
# 55              0
# 56              1
# 57              0
# 58              0
# 59              0
#               ...
#
# [200 rows x 4 columns]

# %%
retweet_favorites = pd.DataFrame(list(db.tweets.find(fields=['created_at','retweet_count','favorite_count'])))
retweet_favorites.head()
# Out:
#                         _id                      created_at  favorite_count  \
# 0  535eef6b40a70518e1474362  Tue Apr 29 00:10:58 +0000 2014               0
# 1  535eef6b40a70518e1474366  Tue Apr 29 00:10:57 +0000 2014               0
# 2  535eef6b40a70518e1474360  Tue Apr 29 00:10:58 +0000 2014               0
# 3  535eef6b40a70518e1474361  Tue Apr 29 00:10:58 +0000 2014               0
# 4  535eef6b40a70518e1474363  Tue Apr 29 00:10:57 +0000 2014               0
#
#    retweet_count
# 0              0
# 1              0
# 2              1
# 3              7
# 4              0
#
# [5 rows x 4 columns]

# %% [markdown]
# `.describe()` is a useful method to get the gist of our data.

# %%
retweet_favorites.describe()
# Out:
#        favorite_count  retweet_count
# count      200.000000     200.000000
# mean         0.010000       2.335000
# std          0.099748      10.251254
# min          0.000000       0.000000
# 25%          0.000000       0.000000
# 50%          0.000000       0.000000
# 75%          0.000000       1.000000
# max          1.000000      92.000000
#
# [8 rows x 2 columns]

# %% [markdown]
# However, when applied to a DataFrame, it only describes numeric columns.

# %%
retweet_favorites.dtypes
# Out:
# _id               object
# created_at        object
# favorite_count     int64
# retweet_count      int64
# dtype: object

# %% [markdown]
# `.describe()` can be called on individual columns (i.e. `Series`), even if they are not numeric.

# %%
retweet_favorites.created_at.describe()
# Out:
# count                                200
# unique                                16
# top       Tue Apr 29 00:10:50 +0000 2014
# freq                                  20
# Name: created_at, dtype: object

# %% [markdown]
# However, in this case `created_at` is being treated as a string, which is not very helpful. We can fix that with `pandas.to_datetime`:

# %%
retweet_favorites.created_at.map(pd.to_datetime).describe()
# Out:
# count                     200
# unique                     16
# first     2014-04-29 00:10:43
# last      2014-04-29 00:10:58
# top       2014-04-29 00:10:50
# freq                       20
# Name: created_at, dtype: object

# %% [markdown]
# Not all that interesting though, since all of these tweets were collected within a couple seconds of each other.

# %% [markdown]
# Mongo allows us to access subfields directly.

# %%
mentions_followers = list(db.tweets.find(fields=['entities.user_mentions', 'user.followers_count']))
pd.DataFrame(mentions_followers).head()
# Out:
#                         _id  \
# 0  535eef6b40a70518e1474362
# 1  535eef6b40a70518e1474366
# 2  535eef6b40a70518e1474360
# 3  535eef6b40a70518e1474361
# 4  535eef6b40a70518e1474363
#
#                                             entities  \
# 0                             {u'user_mentions': []}
# 1                             {u'user_mentions': []}
# 2  {u'user_mentions': [{u'indices': [3, 18], u'sc...
# 3  {u'user_mentions': [{u'indices': [3, 15], u'sc...
# 4                             {u'user_mentions': []}
#
#                          user
# 0   {u'followers_count': 605}
# 1  {u'followers_count': 1062}
# 2  {u'followers_count': 1442}
# 3   {u'followers_count': 545}
# 4  {u'followers_count': 2561}
#
# [5 rows x 3 columns]

# %% [markdown]
# Pandas doesn't know how to parse the sub-documents however, so we must tell it explicitly:

# %%
mentions_followers_df = pd.DataFrame({'user_mentions': len(tweet['entities']['user_mentions']), 
              'followers_count': tweet['user'].get('followers_count')} for tweet in mentions_followers)
mentions_followers_df.head()
# Out:
#    followers_count  user_mentions
# 0              605              0
# 1             1062              0
# 2             1442              1
# 3              545              1
# 4             2561              0
#
# [5 rows x 2 columns]

# %% [markdown]
# Perhaps `user_mentions` and `followers_count` are correlated?

# %%
plt.scatter(mentions_followers_df.user_mentions, mentions_followers_df.followers_count)
mentions_followers_df.corr()
# Out:
#                  followers_count  user_mentions
# followers_count         1.000000       0.026267
# user_mentions           0.026267       1.000000
#
# [2 rows x 2 columns]

# %% [markdown]
# Perhaps not.

# %% [markdown]
# Lab
# ============
# 1-2 Pairs
# ------------

# %% [markdown]
# Raise two fingers if you understand the material well.
# Raise one finger if you understand this material OK.
# Now, 1 find a 2 and sit next to them. While you work through this exercise, only 1's can type.

# %% [markdown]
# The [Yahoo! Where On Earth ID](https://developer.yahoo.com/geo/geoplanet/) of Canada is 23424775.
# Use it to find Twitter trends in Canada and compare it to US trends. What's the difference between them?
#
# - Insert the last 100 tweets for all Canada-only trends into a `canada` collection.
# - Insert the last 100 tweets for all US-only trends into a `us` collections.
# - For this (small and not very representative) sample, which users have the highest `follower_count`?

# %% [markdown]
# Individually:
# ------------
# Find tweets where `'retweet_count': {"$gt": 0}`.
# What is their `count`?
# Is there anything about them that stands out as retweetable?

# %%
CD_WOE_ID = 23424775
US_WOE_ID = 23424977

CD_trends = twitter_api.trends.place(_id=CD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

pprint (CD_trends)
# Out:
# [{u'as_of': u'2014-04-29T00:28:30Z',
#   u'created_at': u'2014-04-29T00:20:26Z',
#   u'locations': [{u'name': u'Canada', u'woeid': 23424775}],
#   u'trends': [{u'name': u'#BuyProblemOniTunes',
#                u'promoted_content': None,
#                u'query': u'%23BuyProblemOniTunes',
#                u'url': u'http://twitter.com/search?q=%23BuyProblemOniTunes'},
#               {u'name': u'#DinahtoMyJane',
#                u'promoted_content': None,
#                u'query': u'%23DinahtoMyJane',
#                u'url': u'http://twitter.com/search?q=%23DinahtoMyJane'},
#               {u'name': u'#WWTO',
#                u'promoted_content': None,
#                u'query': u'%23WWTO',
#                u'url': u'http://twitter.com/search?q=%23WWTO'},
#               {u'name': u'#WeWereBornForThis',
#                u'promoted_content': None,
#                u'query': u'%23WeWereBornForThis',
#                u'url': u'http://twitter.com/search?q=%23WeWereBornForThis'},
#               {u'name': u'#BieberStoleFromParamore',
#                u'promoted_content': None,
#                u'query': u'%23BieberStoleFromParamore',
#                u'url': u'http://twitter.com/search?q=%23BieberStoleFromParamore'},
#               {u'name': u'Ricky Martin',
#                u'promoted_content': None,
#                u'query': u'%22Ricky+Martin%22',
#                u'url': u'http://twitter.com/search?q=%22Ricky+Martin%22'},
#               {u'name': u'Bray Wyatt',
#                u'promoted_content': None,
#                u'query': u'%22Bray+Wyatt%22',
#                u'url': u'http://twitter.com/search?q=%22Bray+Wyatt%22'},
#               {u'name': u'John Cena',
#                u'promoted_content': None,
#                u'query': u'%22John+Cena%22',
#                u'url': u'http://twitter.com/search?q=%22John+Cena%22'},
#               {u'name': u'Don Cherry',
#                u'promoted_content': None,
#                u'query': u'%22Don+Cherry%22',
#                u'url': u'http://twitter.com/search?q=%22Don+Cherry%22'},
#               {u'name': u'Columbus',
#                u'promoted_content': None,
#                u'query': u'Columbus',
#                u'url': u'http://twitter.com/search?q=Columbus'}]}]

# %% [markdown]
# Further exercises:
#
# * Twitter - _Mining-the-Social-Web-2nd-Edition_: [Chapter 1 - Mining Twitter](http://nbviewer.ipython.org/github/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/ipynb/__Chapter%201%20-%20Mining%20Twitter%20%28Full-Text%20Sampler%29.ipynb)
# * Mongo - [Aggregation Framework](http://docs.mongodb.org/manual/aggregation/)

# %%
pprint (us_trends)
# Out:
# [{u'as_of': u'2014-04-29T00:28:30Z',
#   u'created_at': u'2014-04-29T00:27:55Z',
#   u'locations': [{u'name': u'United States', u'woeid': 23424977}],
#   u'trends': [{u'name': u'#bbwlareunion',
#                u'promoted_content': None,
#                u'query': u'%23bbwlareunion',
#                u'url': u'http://twitter.com/search?q=%23bbwlareunion'},
#               {u'name': u'#TagChampionship',
#                u'promoted_content': None,
#                u'query': u'%23TagChampionship',
#                u'url': u'http://twitter.com/search?q=%23TagChampionship'},
#               {u'name': u'#RAWSTLOUIS',
#                u'promoted_content': None,
#                u'query': u'%23RAWSTLOUIS',
#                u'url': u'http://twitter.com/search?q=%23RAWSTLOUIS'},
#               {u'name': u'#FastNLive',
#                u'promoted_content': None,
#                u'query': u'%23FastNLive',
#                u'url': u'http://twitter.com/search?q=%23FastNLive'},
#               {u'name': u'Best Kourtney Kardashian',
#                u'promoted_content': None,
#                u'query': u'%22Best+Kourtney+Kardashian%22',
#                u'url': u'http://twitter.com/search?q=%22Best+Kourtney+Kardashian%22'},
#               {u'name': u'#DisneyKids',
#                u'promoted_content': None,
#                u'query': u'%23DisneyKids',
#                u'url': u'http://twitter.com/search?q=%23DisneyKids'},
#               {u'name': u'Malaysia & Brandi',
#                u'promoted_content': None,
#                u'query': u'%22Malaysia+%26+Brandi%22',
#                u'url': u'http://twitter.com/search?q=%22Malaysia+%26+Brandi%22'},
#               {u'name': u'Tim McCarver',
#                u'promoted_content': None,
#                u'query': u'%22Tim+McCarver%22',
#                u'url': u'http://twitter.com/search?q=%22Tim+McCarver%22'},
#               {u'name': u'James & Peta',
#                u'promoted_content': None,
#                u'query': u'%22James+%26+Peta%22',
#                u'url': u'http://twitter.com/search?q=%22James+%26+Peta%22'},
#               {u'name': u'LeBron vs the Bobcats',
#                u'promoted_content': None,
#                u'query': u'%22LeBron+vs+the+Bobcats%22',
#                u'url': u'http://twitter.com/search?q=%22LeBron+vs+the+Bobcats%22'}]}]

# %%
CD_trends_set = set([trend['name'] for trends in CD_trends
                        for trend in trends['trends']])

us_trends_set = set([trend['name'] for trends in us_trends
                     for trend in trends['trends']]) 

CD_trends_set.difference(us_trends_set)
# Out:
# {u'#BieberStoleFromParamore',
#  u'#BuyProblemOniTunes',
#  u'#DinahtoMyJane',
#  u'#WWTO',
#  u'#WeWereBornForThis',
#  u'Bray Wyatt',
#  u'Columbus',
#  u'Don Cherry',
#  u'John Cena',
#  u'Ricky Martin'}

# %%
CD_trends_set
# Out:
# {u'#BieberStoleFromParamore',
#  u'#BuyProblemOniTunes',
#  u'#DinahtoMyJane',
#  u'#WWTO',
#  u'#WeWereBornForThis',
#  u'Bray Wyatt',
#  u'Columbus',
#  u'Don Cherry',
#  u'John Cena',
#  u'Ricky Martin'}

# %%
CD = CD_trends[0]['trends'][0]['name']

count = 100

search_results = twitter_api.search.tweets(q=CD, count=count)

statuses = search_results['statuses']

# %%
statuses
# Out:
# [{u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Apr 29 00:38:24 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [21, 40],
#      u'text': u'BuyProblemOniTunes'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 158314798,
#      u'id_str': u'158314798',
#      u'indices': [3, 19],
#      u'name': u'Liam Payne',
#      u'screen_name': u'Real_Liam_Payne'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 460941131274940418,
#   u'id_str': u'460941131274940418',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'retweet_count': 60598,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Mon Apr 28 03:51:30 +0000 2014',
#    u'entities': {u'hashtags': [{u'indices': [0, 19],
#       u'text': u'BuyProblemOniTunes'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'favorite_count': 83316,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 460627341753217025,
#    u'id_str': u'460627341753217025',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 60598,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'#BuyProblemOniTunes',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Tue Jun 22 10:19:08 +0000 2010',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'Now stay with me cause im quite quick 5 6 7 8 :)',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'onedirectionmusic.com',
#         u'expanded_url': u'http://www.onedirectionmusic.com',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/4EfbLY37hP'}]}},
#     u'favourites_count': 41,
#     u'follow_request_sent': False,
#     u'followers_count': 16459921,
#     u'following': False,
#     u'friends_count': 15561,
#     u'geo_enabled': True,
#     u'id': 158314798,
#     u'id_str': u'158314798',
#     u'is_translation_enabled': True,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 92032,
#     u'location': u'UK',
#     u'name': u'Liam Payne',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/158314798/1398663334',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/459517566021808129/vi-Y3a8D_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/459517566021808129/vi-Y3a8D_normal.jpeg',
#     u'profile_link_color': u'0084B4',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'Real_Liam_Payne',
#     u'statuses_count': 8121,
#     u'time_zone': u'Hawaii',
#     u'url': u'http://t.co/4EfbLY37hP',
#     u'utc_offset': -36000,
#     u'verified': True}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'RT @Real_Liam_Payne: #BuyProblemOniTunes',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Fri Nov 08 00:32:07 +0000 2013',
#    u'default_profile': True,
#    u'default_profile_image': False,
#    u'description': u"\u01bf\u044f\u0454\u1e6d\u1e6d\u028f \u1e87\u020f\u044f\u0500\u1e61 \u0467\u044f\u0454\u1e45'\u1e6d \u0467\u029f\u1e87\u0467\u028f\u1e61 \u1e6d\u044f\u0217\u0454 \u0467\u1e45\u0500 \u1e6d\u044f\u0217\u0454 \u1e87\u020f\u044f\u0500\u1e61 \u0467\u044f\u0454\u1e45'\u1e6d \u0467\u029f\u1e87\u0467\u028f\u1e61 \u01bf\u044f\u0454\u1e6d\u1e6d\u028f.\u03b9 \u043d\u03b1\u03bd\u0454 \u0455\u03c3 \u043c\u03b1\u0438\u0443 \u03c5\u0438\u0455\u03b1\u03b9\u2202 f\u0454\u0454\u2113\u03b9\u0438g\u0455, \u03b9 \u043a\u0454\u0454\u03c1 \u0442\u043d\u0454\u043c \u0442\u03c3 \u043c\u0443 \u0455\u0454\u2113f \u0432\u0454\xa2\u03b1\u03c5\u0455\u0454 \u0438\u03c3 \u03c3\u0438\u0454 \u03c9\u03b9\u2113\u2113 \u03c5\u0438\u2202\u0454\u044f\u0455\u0442\u03b1\u0438\u2202.",
#    u'entities': {u'description': {u'urls': []}},
#    u'favourites_count': 978,
#    u'follow_request_sent': False,
#    u'followers_count': 451,
#    u'following': False,
#    u'friends_count': 1145,
#    u'geo_enabled': False,
#    u'id': 2181147385,
#    u'id_str': u'2181147385',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 2,
#    u'location': u'',
#    u'name': u'H\u0394RR\u03a8S CURL\u03a8 H\u0394IR',
#    u'notifications': False,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2181147385/1398300863',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/459133217438572544/1RQG_v5A_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/459133217438572544/1RQG_v5A_normal.jpeg',
#    u'profile_link_color': u'0084B4',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'hazzagirl69',
#    u'statuses_count': 1225,
#    u'time_zone': None,
#    u'url': None,
#    u'utc_offset': None,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Apr 29 00:38:22 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [107, 126],
#      u'text': u'BuyProblemOniTunes'},
#     {u'indices': [139, 140], u'text': u'NS'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 290147378,
#      u'id_str': u'290147378',
#      u'indices': [3, 16],
#      u'name': u'Niall Horan Spanish',
#      u'screen_name': u'NiallSpanish'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 460941124501123072,
#   u'id_str': u'460941124501123072',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'es',
#   u'metadata': {u'iso_language_code': u'es', u'result_type': u'recent'},
#   u'place': None,
#   u'retweet_count': 108,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Mon Apr 28 23:47:34 +0000 2014',
#    u'entities': {u'hashtags': [{u'indices': [89, 108],
#       u'text': u'BuyProblemOniTunes'},
#      {u'indices': [137, 140], u'text': u'NS'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'favorite_count': 228,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 460928341097197568,
#    u'id_str': u'460928341097197568',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'es',
#    u'metadata': {u'iso_language_code': u'es', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 108,
#    u'retweeted': False,
#    u'source': u'web',
#    u'text': u'Liam promociono el 27/Abril sin querer el single de Ariana Grande utilizando el hashtag "#BuyProblemOniTunes" y no sabia que significaba #NS',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Fri Apr 29 20:14:37 +0000 2011',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Se toda la vida de 1D y cada movimiento que hacen, sera muy dif\xedcil que escapen de mi. \u201cAnd who am I? That\u2019s a secret I\u2019ll never tell.\u201d - NS',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'onedirectionmusic.com',
#         u'expanded_url': u'http://www.onedirectionmusic.com',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/zUsqChksfv'}]}},
#     u'favourites_count': 12659,
#     u'follow_request_sent': False,
#     u'followers_count': 317853,
#     u'following': False,
#     u'friends_count': 77,
#     u'geo_enabled': False,
#     u'id': 290147378,
#     u'id_str': u'290147378',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'es',
#     u'listed_count': 1169,
#     u'location': u'1/5',
#     u'name': u'Niall Horan Spanish',
#     u'notifications': False,
#     u'profile_background_color': u'C9B39B',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/456533678038859776/q_DllGMF.jpeg',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/456533678038859776/q_DllGMF.jpeg',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/290147378/1397447020',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/2587068362/klf5i0aruzs21vokl9kw_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/2587068362/klf5i0aruzs21vokl9kw_normal.jpeg',
#     u'profile_link_color': u'B89D33',
#     u'profile_sidebar_border_color': u'FFFFFF',
#     u'profile_sidebar_fill_color': u'443C3A',
#     u'profile_text_color': u'BD314D',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'NiallSpanish',
#     u'statuses_count': 44903,
#     u'time_zone': u'Central Time (US & Canada)',
#     u'url': u'http://t.co/zUsqChksfv',
#     u'utc_offset': -18000,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   u'text': u'RT @NiallSpanish: Liam promociono el 27/Abril sin querer el single de Ariana Grande utilizando el hashtag "#BuyProblemOniTunes" y no sabia \u2026',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Thu Jul 14 00:38:59 +0000 2011',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u"My dream?  is of One Direction follow me\u2665 I'm proud Directioner, 0/5 :'(\nThanks for saving my life",
#    u'entities': {u'description': {u'urls': []}},
#    u'favourites_count': 5718,
#    u'follow_request_sent': False,
#    u'followers_count': 65,
#    u'following': False,
#    u'friends_count': 12,
#    u'geo_enabled': False,
#    u'id': 335004169,
#    u'id_str': u'335004169',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en-gb',
#    u'listed_count': 0,
#    u'location': u'',
#    u'name': u'Please Follow me 1D\u2665',
#    u'notifications': False,
#    u'profile_background_color': u'C6E2EE',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000089044476/55dbb78af57b93c32880989ee7474572.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000089044476/55dbb78af57b93c32880989ee7474572.jpeg',
#    u'profile_background_tile': True,
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/434416895312146432/4aC6-Ui3_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/434416895312146432/4aC6-Ui3_normal.jpeg',
#    u'profile_link_color': u'1F98C7',
#    u'profile_sidebar_border_color': u'000000',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'vanessaflores27',
#    u'statuses_count': 2862,
#    u'time_zone': u'Central Time (US & Canada)',
#    u'url': None,
#    u'utc_offset': -18000,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Apr 29 00:38:19 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [0, 19],
#      u'text': u'BuyProblemOniTunes'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 34507480,
#      u'id_str': u'34507480',
#      u'indices': [37, 50],
#      u'name': u'Ariana Grande',
#      u'screen_name': u'ArianaGrande'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 460941111524360192,
#   u'id_str': u'460941111524360192',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'#BuyProblemOniTunes for the princess @ArianaGrande and please follow me Ari!',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Wed Jan 15 21:05:06 +0000 2014',
#    u'default_profile': True,
#    u'default_profile_image': False,
#    u'description': u'#dreamchaser',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'instagram.com/tdaww24',
#        u'expanded_url': u'http://instagram.com/tdaww24',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/T7LmgRtrvu'}]}},
#    u'favourites_count': 19,
#    u'follow_request_sent': False,
#    u'followers_count': 295064,
#    u'following': False,
#    u'friends_count': 9003,
#    u'geo_enabled': False,
#    u'id': 2293391768,
#    u'id_str': u'2293391768',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 11,
#    u'location': u'Los Angeles, CA',
#    u'name': u'Tyler Morrison',
#    u'notifications': False,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': False,
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/460097582531088384/sEWmW72A_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/460097582531088384/sEWmW72A_normal.jpeg',
#    u'profile_link_color': u'0084B4',
#    u'profile_sidebar_border_color': u'C0DEED',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'tylerbelieves',
#    u'statuses_count': 4791,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'url': u'http://t.co/T7LmgRtrvu',
#    u'utc_offset': -14400,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Apr 29 00:38:18 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [21, 40],
#      u'text': u'BuyProblemOniTunes'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 158314798,
#      u'id_str': u'158314798',
#      u'indices': [3, 19],
#      u'name': u'Liam Payne',
#      u'screen_name': u'Real_Liam_Payne'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 460941108457906176,
#   u'id_str': u'460941108457906176',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'retweet_count': 60598,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Mon Apr 28 03:51:30 +0000 2014',
#    u'entities': {u'hashtags': [{u'indices': [0, 19],
#       u'text': u'BuyProblemOniTunes'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'favorite_count': 83316,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 460627341753217025,
#    u'id_str': u'460627341753217025',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 60598,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'#BuyProblemOniTunes',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Tue Jun 22 10:19:08 +0000 2010',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'Now stay with me cause im quite quick 5 6 7 8 :)',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'onedirectionmusic.com',
#         u'expanded_url': u'http://www.onedirectionmusic.com',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/4EfbLY37hP'}]}},
#     u'favourites_count': 41,
#     u'follow_request_sent': False,
#     u'followers_count': 16459921,
#     u'following': False,
#     u'friends_count': 15561,
#     u'geo_enabled': True,
#     u'id': 158314798,
#     u'id_str': u'158314798',
#     u'is_translation_enabled': True,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 92032,
#     u'location': u'UK',
#     u'name': u'Liam Payne',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/158314798/1398663334',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/459517566021808129/vi-Y3a8D_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/459517566021808129/vi-Y3a8D_normal.jpeg',
#     u'profile_link_color': u'0084B4',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'Real_Liam_Payne',
#     u'statuses_count': 8121,
#     u'time_zone': u'Hawaii',
#     u'url': u'http://t.co/4EfbLY37hP',
#     u'utc_offset': -36000,
#     u'verified': True}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'RT @Real_Liam_Payne: #BuyProblemOniTunes',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Tue Aug 20 17:36:55 +0000 2013',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'My fave boyband is much better then yours!! Goint to WWAT on September 11, 2014 !',
#    u'entities': {u'description': {u'urls': []}},
#    u'favourites_count': 4363,
#    u'follow_request_sent': False,
#    u'followers_count': 340,
#    u'following': False,
#    u'friends_count': 468,
#    u'geo_enabled': False,
#    u'id': 1686286704,
#    u'id_str': u'1686286704',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 2,
#    u'location': u'',
#    u'name': u'~ZAYN NOTICE ME~',
#    u'notifications': False,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1686286704/1397504781',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/447920285656698880/ojrGL8Qh_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/447920285656698880/ojrGL8Qh_normal.jpeg',
#    u'profile_link_color': u'0084B4',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Luv_U_Malik',
#    u'statuses_count': 5201,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'url': None,
#    u'utc_offset': -25200,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Apr 29 00:38:11 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [21, 40],
#      u'text': u'BuyProblemOniTunes'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 158314798,
#      u'id_str': u'158314798',
#      u'indices': [3, 19],
#      u'name': u'Liam Payne',
#      u'screen_name': u'Real_Liam_Payne'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 460941078955188224,
#   u'id_str': u'460941078955188224',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'retweet_count': 60598,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Mon Apr 28 03:51:30 +0000 2014',
#    u'entities': {u'hashtags': [{u'indices': [0, 19],
#       u'text': u'BuyProblemOniTunes'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'favorite_count': 83316,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 460627341753217025,
#    u'id_str': u'460627341753217025',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 60598,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'#BuyProblemOniTunes',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Tue Jun 22 10:19:08 +0000 2010',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'Now stay with me cause im quite quick 5 6 7 8 :)',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'onedirectionmusic.com',
#         u'expanded_url': u'http://www.onedirectionmusic.com',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/4EfbLY37hP'}]}},
#     u'favourites_count': 41,
#     u'follow_request_sent': False,
#     u'followers_count': 16459921,
#     u'following': False,
#     u'friends_count': 15561,
#     u'geo_enabled': True,
#     u'id': 158314798,
#     u'id_str': u'158314798',
#     u'is_translation_enabled': True,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 92032,
#     u'location': u'UK',
#     u'name': u'Liam Payne',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/158314798/1398663334',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/459517566021808129/vi-Y3a8D_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/459517566021808129/vi-Y3a8D_normal.jpeg',
#     u'profile_link_color': u'0084B4',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'Real_Liam_Payne',
#     u'statuses_count': 8121,
#     u'time_zone': u'Hawaii',
#     u'url': u'http://t.co/4EfbLY37hP',
#     u'utc_offset': -36000,
#     u'verified': True}},
#   u'source': u'<a href="https://twitter.com/download/android" rel="nofollow">Twitter for  Android</a>',
#   u'text': u'RT @Real_Liam_Payne: #BuyProblemOniTunes',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Tue Jan 29 03:38:18 +0000 2013',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'tumblr Basically rules my life but I sometimes know what reality feels like  #letsbefriends',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'espinoza-alejandra.polyvore.com',
#        u'expanded_url': u'http://espinoza-alejandra.polyvore.com/',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/lKqqq0tZrH'}]}},
#    u'favourites_count': 882,
#    u'follow_request_sent': False,
#    u'followers_count': 273,
#    u'following': False,
#    u'friends_count': 726,
#    u'geo_enabled': False,
#    u'id': 1129954496,
#    u'id_str': u'1129954496',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 0,
#    u'location': u'ily',
#    u'name': u'//ugh//',
#    u'notifications': False,
#    u'profile_background_color': u'1A1B1F',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000135940773/F4Hs0VSt.png',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000135940773/F4Hs0VSt.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1129954496/1387683072',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/459925685474045952/OhXOfiNi_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/459925685474045952/OhXOfiNi_normal.jpeg',
#    u'profile_link_color': u'2FC2EF',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'252429',
#    u'profile_text_color': u'666666',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Alejandra_12892',
#    u'statuses_count': 2703,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'url': u'http://t.co/lKqqq0tZrH',
#    u'utc_offset': -25200,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Apr 29 00:38:11 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [20, 39],
#      u'text': u'BuyProblemOniTunes'}],
#    u'media': [{u'display_url': u'pic.twitter.com/8xFGjcgclf',
#      u'expanded_url': u'http://twitter.com/FrankieJGrande/status/460800633176477697/photo/1',
#      u'id': 460800630680866816,
#      u'id_str': u'460800630680866816',
#      u'indices': [40, 62],
#      u'media_url': u'http://pbs.twimg.com/media/BmUXu3ACUAAalQN.jpg',
#      u'media_url_https': u'https://pbs.twimg.com/media/BmUXu3ACUAAalQN.jpg',
#      u'sizes': {u'large': {u'h': 456, u'resize': u'fit', u'w': 456},
#       u'medium': {u'h': 456, u'resize': u'fit', u'w': 456},
#       u'small': {u'h': 340, u'resize': u'fit', u'w': 340},
#       u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#      u'type': u'photo',
#      u'url': u'http://t.co/8xFGjcgclf'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 70054190,
#      u'id_str': u'70054190',
#      u'indices': [3, 18],
#      u'name': u'Frankie James Grande',
#      u'screen_name': u'FrankieJGrande'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 460941077675917312,
#   u'id_str': u'460941077675917312',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 1373,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Mon Apr 28 15:20:06 +0000 2014',
#    u'entities': {u'hashtags': [{u'indices': [0, 19],
#       u'text': u'BuyProblemOniTunes'}],
#     u'media': [{u'display_url': u'pic.twitter.com/8xFGjcgclf',
#       u'expanded_url': u'http://twitter.com/FrankieJGrande/status/460800633176477697/photo/1',
#       u'id': 460800630680866816,
#       u'id_str': u'460800630680866816',
#       u'indices': [20, 42],
#       u'media_url': u'http://pbs.twimg.com/media/BmUXu3ACUAAalQN.jpg',
#       u'media_url_https': u'https://pbs.twimg.com/media/BmUXu3ACUAAalQN.jpg',
#       u'sizes': {u'large': {u'h': 456, u'resize': u'fit', u'w': 456},
#        u'medium': {u'h': 456, u'resize': u'fit', u'w': 456},
#        u'small': {u'h': 340, u'resize': u'fit', u'w': 340},
#        u'thumb': {u'h': 150, u'resize': u'crop', u'w': 150}},
#       u'type': u'photo',
#       u'url': u'http://t.co/8xFGjcgclf'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'favorite_count': 1905,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 460800633176477697,
#    u'id_str': u'460800633176477697',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 1373,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'#BuyProblemOniTunes http://t.co/8xFGjcgclf',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Sun Aug 30 05:02:24 +0000 2009',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'Actor/Singer/Dancer/Producer/Director/Host/Philanthropist/Person/Personality/ Youtuber/Smiler/Belieber/Arianator :)',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'youtube.com/frankiejgrande',
#         u'expanded_url': u'http://www.youtube.com/frankiejgrande',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/8pDMJ0a3H8'}]}},
#     u'favourites_count': 443,
#     u'follow_request_sent': False,
#     u'followers_count': 513190,
#     u'following': False,
#     u'friends_count': 9110,
#     u'geo_enabled': False,
#     u'id': 70054190,
#     u'id_str': u'70054190',
#     u'is_translation_enabled': True,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 2267,
#     u'location': u'New York, NY',
#     u'name': u'Frankie James Grande',
#     u'notifications': False,
#     u'profile_background_color': u'100A66',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/438773278555901954/W0wHfK-w.png',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/438773278555901954/W0wHfK-w.png',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/70054190/1398303480',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/454426616702062592/SbrHZF6C_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/454426616702062592/SbrHZF6C_normal.jpeg',
#     u'profile_link_color': u'623091',
#     u'profile_sidebar_border_color': u'FFFFFF',
#     u'profile_sidebar_fill_color': u'EFEFEF',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'FrankieJGrande',
#     u'statuses_count': 19847,
#     u'time_zone': u'Pacific Time (US & Canada)',
#     u'url': u'http://t.co/8pDMJ0a3H8',
#     u'utc_offset': -25200,
#     u'verified': True}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'RT @FrankieJGrande: #BuyProblemOniTunes http://t.co/8xFGjcgclf',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Sat Jun 11 04:04:51 +0000 2011',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'a.tumblr.com/tumblr_lsacvi0\u2026',
#        u'expanded_url': u'http://a.tumblr.com/tumblr_lsacvi0Jf81qkdlzoo1.mp3',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/AXGpfxXLBx'}]}},
#    u'favourites_count': 19863,
#    u'follow_request_sent': False,
#    u'followers_count': 205,
#    u'following': False,
#    u'friends_count': 98,
#    u'geo_enabled': True,
#    u'id': 314992414,
#    u'id_str': u'314992414',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 1,
#    u'location': u'Oakland, CA',
#    u'name': u'Ashley Nguyen',
#    u'notifications': False,
#    u'profile_background_color': u'08020F',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/432424725575245824/ocaHGMy2.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/432424725575245824/ocaHGMy2.jpeg',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/314992414/1390083798',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/445039639095566336/mASzN3Ma_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/445039639095566336/mASzN3Ma_normal.jpeg',
#    u'profile_link_color': u'CFC0C0',
#    u'profile_sidebar_border_color': u'000000',
#    u'profile_sidebar_fill_color': u'7AC3EE',
#    u'profile_text_color': u'8C0CED',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'baybeeashleyan',
#    u'statuses_count': 5269,
#    u'time_zone': u'Arizona',
#    u'url': u'http://t.co/AXGpfxXLBx',
#    u'utc_offset': -25200,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Apr 29 00:38:09 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [21, 40],
#      u'text': u'BuyProblemOniTunes'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 158314798,
#      u'id_str': u'158314798',
#      u'indices': [3, 19],
#      u'name': u'Liam Payne',
#      u'screen_name': u'Real_Liam_Payne'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 460941067232092160,
#   u'id_str': u'460941067232092160',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'retweet_count': 60598,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Mon Apr 28 03:51:30 +0000 2014',
#    u'entities': {u'hashtags': [{u'indices': [0, 19],
#       u'text': u'BuyProblemOniTunes'}],
#     u'symbols': [],
#     u'urls': [],
#     u'user_mentions': []},
#    u'favorite_count': 83316,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 460627341753217025,
#    u'id_str': u'460627341753217025',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'retweet_count': 60598,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u'#BuyProblemOniTunes',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Tue Jun 22 10:19:08 +0000 2010',
#     u'default_profile': True,
#     u'default_profile_image': False,
#     u'description': u'Now stay with me cause im quite quick 5 6 7 8 :)',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'onedirectionmusic.com',
#         u'expanded_url': u'http://www.onedirectionmusic.com',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/4EfbLY37hP'}]}},
#     u'favourites_count': 41,
#     u'follow_request_sent': False,
#     u'followers_count': 16459921,
#     u'following': False,
#     u'friends_count': 15561,
#     u'geo_enabled': True,
#     u'id': 158314798,
#     u'id_str': u'158314798',
#     u'is_translation_enabled': True,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 92032,
#     u'location': u'UK',
#     u'name': u'Liam Payne',
#     u'notifications': False,
#     u'profile_background_color': u'C0DEED',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/158314798/1398663334',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/459517566021808129/vi-Y3a8D_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/459517566021808129/vi-Y3a8D_normal.jpeg',
#     u'profile_link_color': u'0084B4',
#     u'profile_sidebar_border_color': u'C0DEED',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'Real_Liam_Payne',
#     u'statuses_count': 8121,
#     u'time_zone': u'Hawaii',
#     u'url': u'http://t.co/4EfbLY37hP',
#     u'utc_offset': -36000,
#     u'verified': True}},
#   u'source': u'web',
#   u'text': u'RT @Real_Liam_Payne: #BuyProblemOniTunes',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Wed May 16 19:19:12 +0000 2012',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'As\xed que cari\xf1o sujeta mi coraz\xf3n , necesito que no me dejes caer , yo siempre resistir\xe9 PORQUE TU ME HACES FUERTE  \u2693 \u02b7\u02b0\u1d49\u02b3\u1d49 \u02b7\u1d49 \u1d43\u02b3\u1d49',
#    u'entities': {u'description': {u'urls': []}},
#    u'favourites_count': 12886,
#    u'follow_request_sent': False,
#    u'followers_count': 537,
#    u'following': False,
#    u'friends_count': 534,
#    u'geo_enabled': True,
#    u'id': 582172281,
#    u'id_str': u'582172281',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'es',
#    u'listed_count': 0,
#    u'location': u'1D \u028f\u1d0f\u1d1c  \u1d0d\u1d00\u1d0b\u1d07 \u1d0d\u1d07 s\u1d1b\u0280\u1d0f\u0274\u0262\u2661',
#    u'name': u'Jaz a WWAT 2014 \u2661',
#    u'notifications': False,
#    u'profile_background_color': u'FFFFFF',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/460106780123492352/1izK0Ksd.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/460106780123492352/1izK0Ksd.jpeg',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/582172281/1398471544',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/460515414888296448/tQRn2ohc_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/460515414888296448/tQRn2ohc_normal.jpeg',
#    u'profile_link_color': u'480EE6',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'EFEFEF',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'1D_YMMSTRONG',
#    u'statuses_count': 18516,
#    u'time_zone': u'Buenos Aires',
#    u'url': None,
#    u'utc_offset': -10800,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Apr 29 00:38:07 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [82, 101],
#      u'text': u'BuyProblemOniTunes'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'vine.co/v/Mvtj2KjrEKx',
#      u'expanded_url': u'https://vine.co/v/Mvtj2KjrEKx',
#      u'indices': [102, 125],
#      u'url': u'https://t.co/kG7gx1C5MG'}],
#    u'user_mentions': [{u'id': 2417775721,
#      u'id_str': u'2417775721',
#      u'indices': [3, 16],
#      u'name': u'\u265bari please',
#      u'screen_name': u'Mariiakrivko'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 460941059405537281,
#   u'id_str': u'460941059405537281',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 9,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Tue Apr 29 00:11:06 +0000 2014',
#    u'entities': {u'hashtags': [{u'indices': [64, 83],
#       u'text': u'BuyProblemOniTunes'}],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'vine.co/v/Mvtj2KjrEKx',
#       u'expanded_url': u'https://vine.co/v/Mvtj2KjrEKx',
#       u'indices': [84, 107],
#       u'url': u'https://t.co/kG7gx1C5MG'}],
#     u'user_mentions': []},
#    u'favorite_count': 4,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 460934263550930945,
#    u'id_str': u'460934263550930945',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 9,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/tweetbutton" rel="nofollow">Tweet Button</a>',
#    u'text': u'Beat drop pt. 4 (\u266b Problem [feat. iggy Azalea] \u2013 Ariana Grande) #BuyProblemOniTunes https://t.co/kG7gx1C5MG',
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Sat Mar 29 17:50:26 +0000 2014',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u"I love music \u2022 I'm always smiling and laughing . My Hero @justinbieber . My baby @MadisonElleBeer and @ArianaGrande  \u262f \u263d \u2741",
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'instagram.com/mariiakrivko',
#         u'expanded_url': u'http://instagram.com/mariiakrivko',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/3M9gylmoct'}]}},
#     u'favourites_count': 40,
#     u'follow_request_sent': False,
#     u'followers_count': 132,
#     u'following': False,
#     u'friends_count': 106,
#     u'geo_enabled': True,
#     u'id': 2417775721,
#     u'id_str': u'2417775721',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'ru',
#     u'listed_count': 0,
#     u'location': u'Belarus. Slytsk.',
#     u'name': u'\u265bari please',
#     u'notifications': False,
#     u'profile_background_color': u'E8CCE8',
#     u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/459449478102020096/5LweEzIz.png',
#     u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/459449478102020096/5LweEzIz.png',
#     u'profile_background_tile': True,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2417775721/1398469703',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/460923122590302209/aeISYdJZ_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/460923122590302209/aeISYdJZ_normal.jpeg',
#     u'profile_link_color': u'D578E6',
#     u'profile_sidebar_border_color': u'FFFFFF',
#     u'profile_sidebar_fill_color': u'DDEEF6',
#     u'profile_text_color': u'333333',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'Mariiakrivko',
#     u'statuses_count': 4065,
#     u'time_zone': u'Abu Dhabi',
#     u'url': u'http://t.co/3M9gylmoct',
#     u'utc_offset': 14400,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'RT @Mariiakrivko: Beat drop pt. 4 (\u266b Problem [feat. iggy Azalea] \u2013 Ariana Grande) #BuyProblemOniTunes https://t.co/kG7gx1C5MG',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Sat Nov 09 02:22:56 +0000 2013',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u"holy shit it's the aliens I'm screwed",
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'smarturl.it/ArianaProblemiT',
#        u'expanded_url': u'http://smarturl.it/ArianaProblemiT',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/DXtwErutg5'}]}},
#    u'favourites_count': 11993,
#    u'follow_request_sent': False,
#    u'followers_count': 2414,
#    u'following': False,
#    u'friends_count': 2148,
#    u'geo_enabled': False,
#    u'id': 2183415686,
#    u'id_str': u'2183415686',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 29,
#    u'location': u'Honeymoon ave.',
#    u'name': u"Ariana's Wife",
#    u'notifications': False,
#    u'profile_background_color': u'000000',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000180170854/DfjjfPHV.png',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000180170854/DfjjfPHV.png',
#    u'profile_background_tile': False,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2183415686/1398383274',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/459478687453155329/LSCYh-MA_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/459478687453155329/LSCYh-MA_normal.jpeg',
#    u'profile_link_color': u'0084B4',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'ArianaIsFetch',
#    u'statuses_count': 32435,
#    u'time_zone': u'Pacific Time (US & Canada)',
#    u'url': u'http://t.co/DXtwErutg5',
#    u'utc_offset': -25200,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Apr 29 00:38:03 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [36, 55],
#      u'text': u'BuyProblemOniTunes'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': [{u'id': 34507480,
#      u'id_str': u'34507480',
#      u'indices': [0, 13],
#      u'name': u'Ariana Grande',
#      u'screen_name': u'ArianaGrande'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 460941045724094464,
#   u'id_str': u'460941045724094464',
#   u'in_reply_to_screen_name': u'ArianaGrande',
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': 34507480,
#   u'in_reply_to_user_id_str': u'34507480',
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   u'text': u'@ArianaGrande follow me please ari! #BuyProblemOniTunes \U0001f44d\U0001f49c\U0001f49e\U0001f495',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Thu Aug 02 21:28:10 +0000 2012',
#    u'default_profile': False,
#    u'default_profile_image': False,
# ...
#    u'profile_sidebar_fill_color': u'0D0806',
#    u'profile_text_color': u'544C45',
#    u'profile_use_background_image': False,
#    u'protected': False,
#    u'screen_name': u'5sostruelife',
#    u'statuses_count': 13215,
#    u'time_zone': u'Mexico City',
#    u'url': u'https://t.co/MlxVM7gOrm',
#    u'utc_offset': -18000,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Apr 29 00:35:36 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [31, 50],
#      u'text': u'buyproblemonitunes'},
#     {u'indices': [51, 64], u'text': u'arianagrande'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'instagram.com/p/nWkR_dRJo0/',
#      u'expanded_url': u'http://instagram.com/p/nWkR_dRJo0/',
#      u'indices': [65, 87],
#      u'url': u'http://t.co/ewtqFyRL5W'}],
#    u'user_mentions': []},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 460940426124742656,
#   u'id_str': u'460940426124742656',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#   u'text': u'This song is freaking perfect. #buyproblemonitunes #arianagrande http://t.co/ewtqFyRL5W',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Sat Jun 09 01:45:10 +0000 2012',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Youtubers, Bands, Boybands, and Books\n\r\nIG:_foreveryoung_13_',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'perksofbeingdaniyela.tumblr.com',
#        u'expanded_url': u'http://perksofbeingdaniyela.tumblr.com',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/5UyfpcHoIq'}]}},
#    u'favourites_count': 7286,
#    u'follow_request_sent': False,
#    u'followers_count': 1323,
#    u'following': False,
#    u'friends_count': 1223,
#    u'geo_enabled': False,
#    u'id': 603218054,
#    u'id_str': u'603218054',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 10,
#    u'location': u'Neverland ',
#    u'name': u'Daniyela\u271e',
#    u'notifications': False,
#    u'profile_background_color': u'BADFCD',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/378800000068969272/c6e23d0ebb2d01816453332201adb176.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/378800000068969272/c6e23d0ebb2d01816453332201adb176.jpeg',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/603218054/1395438972',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/458648743743852544/Ig3fXmmD_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/458648743743852544/Ig3fXmmD_normal.jpeg',
#    u'profile_link_color': u'FF0000',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'FFF7CC',
#    u'profile_text_color': u'0C3E53',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Daniyelaa___',
#    u'statuses_count': 9587,
#    u'time_zone': u'Eastern Time (US & Canada)',
#    u'url': u'http://t.co/5UyfpcHoIq',
#    u'utc_offset': -14400,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Apr 29 00:35:35 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [0, 19],
#      u'text': u'BuyProblemOniTunes'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'smarturl.it/ArianaProblemiT',
#      u'expanded_url': u'http://smarturl.it/ArianaProblemiT',
#      u'indices': [55, 77],
#      u'url': u'http://t.co/2o30NJSnB5'}],
#    u'user_mentions': [{u'id': 34507480,
#      u'id_str': u'34507480',
#      u'indices': [23, 36],
#      u'name': u'Ariana Grande',
#      u'screen_name': u'ArianaGrande'},
#     {u'id': 153694176,
#      u'id_str': u'153694176',
#      u'indices': [43, 54],
#      u'name': u'IGGY AZALEA',
#      u'screen_name': u'IGGYAZALEA'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 460940422874157056,
#   u'id_str': u'460940422874157056',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'web',
#   u'text': u'#BuyProblemOniTunes by @ArianaGrande &amp; @IGGYAZALEA http://t.co/2o30NJSnB5',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Sun Mar 30 02:20:09 +0000 2014',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Never give up, the only thing standing between you and your dreams is your fear. \u272b \u2014 Support AG&MG too \u273a #BuyProblem \u270c',
#    u'entities': {u'description': {u'urls': []}},
#    u'favourites_count': 62,
#    u'follow_request_sent': False,
#    u'followers_count': 130,
#    u'following': False,
#    u'friends_count': 76,
#    u'geo_enabled': False,
#    u'id': 2418309733,
#    u'id_str': u'2418309733',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en-gb',
#    u'listed_count': 0,
#    u'location': u'NYC',
#    u'name': u'Julia',
#    u'notifications': False,
#    u'profile_background_color': u'F5F5F5',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/460919023794806785/1Qt13K11.png',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/460919023794806785/1Qt13K11.png',
#    u'profile_background_tile': True,
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/460925821763338240/AK3SUunL_normal.png',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/460925821763338240/AK3SUunL_normal.png',
#    u'profile_link_color': u'000000',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'mostrdope',
#    u'statuses_count': 1990,
#    u'time_zone': u'Brasilia',
#    u'url': None,
#    u'utc_offset': -10800,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Apr 29 00:35:31 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [0, 19],
#      u'text': u'BuyProblemOniTunes'}],
#    u'symbols': [],
#    u'urls': [],
#    u'user_mentions': []},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 460940408823230464,
#   u'id_str': u'460940408823230464',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'retweet_count': 0,
#   u'retweeted': False,
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u'#BuyProblemOniTunes',
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Sun Feb 16 22:07:16 +0000 2014',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u'Yours truly who?',
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'ask.fm/Grandesprism',
#        u'expanded_url': u'http://ask.fm/Grandesprism',
#        u'indices': [0, 22],
#        u'url': u'http://t.co/hTESspWZ4e'}]}},
#    u'favourites_count': 281,
#    u'follow_request_sent': False,
#    u'followers_count': 1519,
#    u'following': False,
#    u'friends_count': 1290,
#    u'geo_enabled': False,
#    u'id': 2347634615,
#    u'id_str': u'2347634615',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 4,
#    u'location': u"isaac's bag",
#    u'name': u'problem',
#    u'notifications': False,
#    u'profile_background_color': u'EBC1E5',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/443552221616029696/0yFq1lOe.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/443552221616029696/0yFq1lOe.jpeg',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2347634615/1397421964',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/460824388171210752/vKBc85Af_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/460824388171210752/vKBc85Af_normal.jpeg',
#    u'profile_link_color': u'DB67D9',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'Grandesprism',
#    u'statuses_count': 849,
#    u'time_zone': None,
#    u'url': u'http://t.co/hTESspWZ4e',
#    u'utc_offset': None,
#    u'verified': False}},
#  {u'contributors': None,
#   u'coordinates': None,
#   u'created_at': u'Tue Apr 29 00:35:28 +0000 2014',
#   u'entities': {u'hashtags': [{u'indices': [56, 75],
#      u'text': u'BuyProblemOniTunes'},
#     {u'indices': [76, 98], u'text': u'BuyProblemOniTunesNow'}],
#    u'symbols': [],
#    u'urls': [{u'display_url': u'Smarturl.it/ArianaProblemiT',
#      u'expanded_url': u'http://Smarturl.it/ArianaProblemiT',
#      u'indices': [100, 122],
#      u'url': u'http://t.co/XxI6sfDeKt'}],
#    u'user_mentions': [{u'id': 1663892185,
#      u'id_str': u'1663892185',
#      u'indices': [3, 17],
#      u'name': u'Jen',
#      u'screen_name': u'GrandeMomentz'}]},
#   u'favorite_count': 0,
#   u'favorited': False,
#   u'geo': None,
#   u'id': 460940395979890688,
#   u'id_str': u'460940395979890688',
#   u'in_reply_to_screen_name': None,
#   u'in_reply_to_status_id': None,
#   u'in_reply_to_status_id_str': None,
#   u'in_reply_to_user_id': None,
#   u'in_reply_to_user_id_str': None,
#   u'lang': u'en',
#   u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#   u'place': None,
#   u'possibly_sensitive': False,
#   u'retweet_count': 3,
#   u'retweeted': False,
#   u'retweeted_status': {u'contributors': None,
#    u'coordinates': None,
#    u'created_at': u'Tue Apr 29 00:24:38 +0000 2014',
#    u'entities': {u'hashtags': [{u'indices': [37, 56],
#       u'text': u'BuyProblemOniTunes'},
#      {u'indices': [57, 79], u'text': u'BuyProblemOniTunesNow'}],
#     u'symbols': [],
#     u'urls': [{u'display_url': u'Smarturl.it/ArianaProblemiT',
#       u'expanded_url': u'http://Smarturl.it/ArianaProblemiT',
#       u'indices': [81, 103],
#       u'url': u'http://t.co/XxI6sfDeKt'}],
#     u'user_mentions': []},
#    u'favorite_count': 2,
#    u'favorited': False,
#    u'geo': None,
#    u'id': 460937668210487296,
#    u'id_str': u'460937668210487296',
#    u'in_reply_to_screen_name': None,
#    u'in_reply_to_status_id': None,
#    u'in_reply_to_status_id_str': None,
#    u'in_reply_to_user_id': None,
#    u'in_reply_to_user_id_str': None,
#    u'lang': u'en',
#    u'metadata': {u'iso_language_code': u'en', u'result_type': u'recent'},
#    u'place': None,
#    u'possibly_sensitive': False,
#    u'retweet_count': 3,
#    u'retweeted': False,
#    u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    u'text': u"YOU WON'T REGRET BUYING THIS SINGLE! #BuyProblemOniTunes #BuyProblemOniTunesNow  http://t.co/XxI6sfDeKt",
#    u'truncated': False,
#    u'user': {u'contributors_enabled': False,
#     u'created_at': u'Mon Aug 12 01:38:03 +0000 2013',
#     u'default_profile': False,
#     u'default_profile_image': False,
#     u'description': u'\u2022 \u2022 \u2022 good times man \u2022 \u2022 \u2022',
#     u'entities': {u'description': {u'urls': []},
#      u'url': {u'urls': [{u'display_url': u'Smarturl.it/ArianaProblemiT',
#         u'expanded_url': u'http://Smarturl.it/ArianaProblemiT',
#         u'indices': [0, 22],
#         u'url': u'http://t.co/3D8Yd5dZJa'}]}},
#     u'favourites_count': 9601,
#     u'follow_request_sent': False,
#     u'followers_count': 4585,
#     u'following': False,
#     u'friends_count': 2213,
#     u'geo_enabled': False,
#     u'id': 1663892185,
#     u'id_str': u'1663892185',
#     u'is_translation_enabled': False,
#     u'is_translator': False,
#     u'lang': u'en',
#     u'listed_count': 32,
#     u'location': u'',
#     u'name': u'Jen',
#     u'notifications': False,
#     u'profile_background_color': u'1A1B1F',
#     u'profile_background_image_url': u'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     u'profile_background_tile': False,
#     u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/1663892185/1398122854',
#     u'profile_image_url': u'http://pbs.twimg.com/profile_images/458568290898808833/gd5iR6A8_normal.jpeg',
#     u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/458568290898808833/gd5iR6A8_normal.jpeg',
#     u'profile_link_color': u'2FC2EF',
#     u'profile_sidebar_border_color': u'181A1E',
#     u'profile_sidebar_fill_color': u'252429',
#     u'profile_text_color': u'666666',
#     u'profile_use_background_image': True,
#     u'protected': False,
#     u'screen_name': u'GrandeMomentz',
#     u'statuses_count': 25791,
#     u'time_zone': u'Atlantic Time (Canada)',
#     u'url': u'http://t.co/3D8Yd5dZJa',
#     u'utc_offset': -10800,
#     u'verified': False}},
#   u'source': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   u'text': u"RT @GrandeMomentz: YOU WON'T REGRET BUYING THIS SINGLE! #BuyProblemOniTunes #BuyProblemOniTunesNow  http://t.co/XxI6sfDeKt",
#   u'truncated': False,
#   u'user': {u'contributors_enabled': False,
#    u'created_at': u'Sat Apr 12 09:38:36 +0000 2014',
#    u'default_profile': False,
#    u'default_profile_image': False,
#    u'description': u"questioning my sexuality because of ariana's existance \u2661 ariana followed 4.24.14",
#    u'entities': {u'description': {u'urls': []},
#     u'url': {u'urls': [{u'display_url': u'twitter.com/ArianaGrande/s\u2026',
#        u'expanded_url': u'https://twitter.com/ArianaGrande/status/12435350789',
#        u'indices': [0, 23],
#        u'url': u'https://t.co/MlxVM7gOrm'}]}},
#    u'favourites_count': 1040,
#    u'follow_request_sent': False,
#    u'followers_count': 2374,
#    u'following': False,
#    u'friends_count': 878,
#    u'geo_enabled': False,
#    u'id': 2439783798,
#    u'id_str': u'2439783798',
#    u'is_translation_enabled': False,
#    u'is_translator': False,
#    u'lang': u'en',
#    u'listed_count': 25,
#    u'location': u'',
#    u'name': u'alyssa',
#    u'notifications': False,
#    u'profile_background_color': u'C0DEED',
#    u'profile_background_image_url': u'http://pbs.twimg.com/profile_background_images/455896720442789889/o_nLW2Mi.jpeg',
#    u'profile_background_image_url_https': u'https://pbs.twimg.com/profile_background_images/455896720442789889/o_nLW2Mi.jpeg',
#    u'profile_background_tile': True,
#    u'profile_banner_url': u'https://pbs.twimg.com/profile_banners/2439783798/1398398149',
#    u'profile_image_url': u'http://pbs.twimg.com/profile_images/459541286354034691/nmAPZimQ_normal.jpeg',
#    u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/459541286354034691/nmAPZimQ_normal.jpeg',
#    u'profile_link_color': u'0084B4',
#    u'profile_sidebar_border_color': u'FFFFFF',
#    u'profile_sidebar_fill_color': u'DDEEF6',
#    u'profile_text_color': u'333333',
#    u'profile_use_background_image': True,
#    u'protected': False,
#    u'screen_name': u'aributeraxqueen',
#    u'statuses_count': 3364,
#    u'time_zone': None,
#    u'url': u'https://t.co/MlxVM7gOrm',
#    u'utc_offset': None,
#    u'verified': False}}]

# %%
len(statuses)
# Out:
# 100

# %%
us_trends_set.difference(CD_trends_set)
# Out:
# {u'#DisneyKids',
#  u'#FastNLive',
#  u'#RAWSTLOUIS',
#  u'#TagChampionship',
#  u'#bbwlareunion',
#  u'Best Kourtney Kardashian',
#  u'James & Peta',
#  u'LeBron vs the Bobcats',
#  u'Malaysia & Brandi',
#  u'Tim McCarver'}

# %%
us = us_trends[0]['trends'][0]['name']

count = 100

search_results = twitter_api.search.tweets(q=us, count=count)

statuses = search_results['statuses']

# %%
len(statuses)
# Out:
# 100

# %%
mentions_followers_uscd = list(db.tweets.find(fields=['entities.user_mentions', 'user.followers_count']))
pd.DataFrame(mentions_followers).head()
# Out:
#                         _id  \
# 0  535eef6b40a70518e1474362
# 1  535eef6b40a70518e1474366
# 2  535eef6b40a70518e1474360
# 3  535eef6b40a70518e1474361
# 4  535eef6b40a70518e1474363
#
#                                             entities  \
# 0                             {u'user_mentions': []}
# 1                             {u'user_mentions': []}
# 2  {u'user_mentions': [{u'indices': [3, 18], u'sc...
# 3  {u'user_mentions': [{u'indices': [3, 15], u'sc...
# 4                             {u'user_mentions': []}
#
#                          user
# 0   {u'followers_count': 605}
# 1  {u'followers_count': 1062}
# 2  {u'followers_count': 1442}
# 3   {u'followers_count': 545}
# 4  {u'followers_count': 2561}
#
# [5 rows x 3 columns]

# %%
mentions_followers_df_uscd = pd.DataFrame({'user_mentions': len(tweet['entities']['user_mentions']), 
              'followers_count': tweet['user'].get('followers_count')} for tweet in mentions_followers)
mentions_followers_df_uscd.head()
# Out:
#    followers_count  user_mentions
# 0              605              0
# 1             1062              0
# 2             1442              1
# 3              545              1
# 4             2561              0
#
# [5 rows x 2 columns]

# %% [markdown]
# Next week:
# ==============
# Exploring Data
# --------------

# %%
popular_tweets_uscd = db.tweets.find({'retweet_count': {"$gt": 0}})
popular_tweets_uscd.count()
# Out:
# 62

# %%
retweet_favorites_uscd = pd.DataFrame(list(db.tweets.find(fields=['created_at','retweet_count','favorite_count'])))
retweet_favorites.head()
# Out:
#                         _id                      created_at  favorite_count  \
# 0  535eef6b40a70518e1474362  Tue Apr 29 00:10:58 +0000 2014               0
# 1  535eef6b40a70518e1474366  Tue Apr 29 00:10:57 +0000 2014               0
# 2  535eef6b40a70518e1474360  Tue Apr 29 00:10:58 +0000 2014               0
# 3  535eef6b40a70518e1474361  Tue Apr 29 00:10:58 +0000 2014               0
# 4  535eef6b40a70518e1474363  Tue Apr 29 00:10:57 +0000 2014               0
#
#    retweet_count
# 0              0
# 1              0
# 2              1
# 3              7
# 4              0
#
# [5 rows x 4 columns]

# %%
retweet_favorites_uscd.describe()
# Out:
#        favorite_count  retweet_count
# count      200.000000     200.000000
# mean         0.010000       2.335000
# std          0.099748      10.251254
# min          0.000000       0.000000
# 25%          0.000000       0.000000
# 50%          0.000000       0.000000
# 75%          0.000000       1.000000
# max          1.000000      92.000000
#
# [8 rows x 2 columns]
